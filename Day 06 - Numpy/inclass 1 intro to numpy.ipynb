# %% [markdown]
# # $$NumPy$$

# %% [markdown]
# - NumPy is a library
# - to install you need the package in your system
# -
# - you use the pip module to do that ---  a module within our python interpreter
# - pip helps us install libraries

# %% [markdown]
# - NumPy helps us create ndarrays ---> N - Dimensional Array
# -

# %%
# pip install numpy

# %%
import numpy as np

array_1d = np.array([1,2,3,4,5])

# single dimension array

# %%
type(array_1d) # numpy.ndarray
# Out:
# numpy.ndarray
