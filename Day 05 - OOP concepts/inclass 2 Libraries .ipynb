# %% [markdown]
# # $$Libraries$$

# %% [markdown]
# - a library is a collection of modules and packages that provides prewritten code
# -
# - Example: 'Numpy' - needs to be installed
#     - a third party library -
#     - Focus is Numerical/mathematical operations
# ```python
# import numpy as np
# ```
# - Example:
#     - `math` - inbuilt library
#     - `time` -
#     - `system` - sys
#     -

# %%
import math
import sys

math.pi # pi
math.e # natural exponent

math.sqrt(16)

# %% [markdown]
# Why we use them?
# - Code Reusability
# - Simplified Development
# - Huge Community Support - faced an issue with a open source library, developer community can just come and help you
# -

# %% [markdown]
# About code reusability
#
#
# Variables ---> Function ---> Classes (attributes and methods) ---> Library

# %% [markdown]
# - Generally installing libraries:
# ```python
# pip install libarary1 library2
# ```
# Important libraries:
# 1. `Numpy` - numerical computation
# 2. `Pandas` - data cleaning, transformation etc
# 3. `Matplotlib` - visualizations
# 4. `Seaborn` - Visualizations
# 5. `Scikit-learn` - used for Machine Learning
# 6. `Tensorflow` and `PyTorch` - used for Deep Learning
# 7. `Flask` and `Django` - used for web development

# %% [markdown]
# Libraries contain:
# - Modules - any `.py` files
# - Folders that contain modules
# - Classes, functions etc
# - Config files as well

# %% [markdown]
# #### Create our own library and use it
# - Understand Object Oriented Programming along the way
# -

# %%
# School Management System
import SchoolManagementSystem as sms

# from SchoolManagementSystem import school_member

# %%
# school_member.welcome_message()

# %%
import SchoolManagementSystem as sms

# %%
sms.school()

# %%
# if you wish to not overburden your system
# only bring in the necessary parts of a library
from SchoolManagementSystem import school_members
# Out:
# ----init SMS libarary ASSEMBLE----
# ----members SMS libarary ASSEMBLE----

# %%
instructor1 = school_members.Instructor("idrees", "Instructor",["ai ml", 'data analytics', "generative AI", "Deep Learning"])

# %%
instructor1.get_info()
# Out:
# Name: idrees
# Role: Instructor
# School: Nexperts School of Engineering
